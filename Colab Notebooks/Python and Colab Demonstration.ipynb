# %% [markdown]
# #This is my first real notebook!

# %% [markdown]
# ##This is one plus one

# %%
1+1 #This is one plus one
# Out:
# 2

# %% [markdown]
# ##This is five plus five!

# %%
5+5 #This is five plus five

# this is a code cell
# one more comment
# Out:
# 10

# %%
# this is empty for now

# %%
result_one_plus_one = 1 + 1
result_one_plus_one
# Out:
# 2

# %%
'hello world!'
# Out:
# 'hello world!'

# %%
hw = 'hello world!'

# %%
float_number = 5.555555

# %%
type(5+5.2)
# Out:
# float

# %%
a = 5
a = 'hello'

# Last assignment of a variable (example 'a') is the one it recognizes and is assigned.

# %% [markdown]
# After finishing an assignment go to runtime and do a factory reset runtime then do run all to run each code block in order and make sure it all works

# %%
a
# Out:
# 'hello'

# %%
float_number+float_number
# Out:
# 11.11111

# %%
hw+hw
# Out:
# 'hello world!hello world!'

# %%
'hi'+'5'
# Out:
# 'hi5'

# %%
'5'+'5'
# Out:
# '55'

# %%
5+5
# Out:
# 10

# %%
#not a good way to state variables
some_var = "a"
other_var = "b"
another_var = "c"

# %%
#good way to state variables
str_list = ['a','b','c']

# %%
num_list = [1,2,3]

# %%
# remember that python is 0 based, meaning lists of variables (fisrt postion) is always 0.
str_list[0]
# Out:
# 'a'

# %%
num_list[0]
# Out:
# 1

# %%
str_list+num_list
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
new_list = str_list+num_list

# %%
type(new_list[5])
# Out:
# int

# %%
type((1,2,'g'))
# Out:
# tuple

# %%
sum(num_list)
# Out:
# 6

# %%
import numpy as np

# %%
np.median(num_list)
# Out:
# 2.0

# %%
np.mean(num_list)
# Out:
# 2.0

# %%
np.std(num_list)
# Out:
# 0.816496580927726

# %%
import pandas as pd

# %%
my_df = pd.DataFrame({'first_name':['xio','sushi','matt'],
              'purchase_amount':[300.00,200.00,400.00]})
my_df
# Out:
#   first_name  purchase_amount
# 0        xio            300.0
# 1      sushi            200.0
# 2       matt            400.0

# %%
my_df.shape
# (rows, columns)
# Out:
# (3, 2)

# %%
# to get how many rows
my_df.shape[0]
# Out:
# 3

# %%
# to get how many columns
my_df.shape[1]
# Out:
# 2

# %%
my_df.purchase_amount.sum()
# Out:
# 900.0

# %%
my_df['purchase_amount'].sum()
# Out:
# 900.0

# %%
my_df.sort_values('purchase_amount',ascending=False)
# Out:
#   first_name  purchase_amount
# 2       matt            400.0
# 0        xio            300.0
# 1      sushi            200.0

# %%
my_df['over_200'] = my_df['purchase_amount'] > 200
my_df
# Out:
#   first_name  purchase_amount  over_200
# 0        xio            300.0      True
# 1      sushi            200.0     False
# 2       matt            400.0      True

# %%
# boolean value data type true or false or 0 and 1
my_df[my_df['over_200']]
# Out:
#   first_name  purchase_amount  over_200
# 0        xio            300.0      True
# 2       matt            400.0      True

# %%
my_df[my_df['purchase_amount']<300]
# Out:
#   first_name  purchase_amount  over_200
# 1      sushi            200.0     False

# %%
my_df = my_df.drop('over_200',axis=1)
my_df
# Out:
#   first_name  purchase_amount
# 0        xio            300.0
# 1      sushi            200.0
# 2       matt            400.0
