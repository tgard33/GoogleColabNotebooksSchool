# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# Hi I'm just text, I'm not code.

# %%
# Retrieve csv file from google drive by mapping the folder from Google Drive. 
# Must be done each time session expires.
# Insert a code cell to include to following lines of code in each  
# Colab notebook to access data files saved in Google Drive of your account.
# Do not run the code in this cell yet. First review the explanation and 
# screen dumps to understand the steps to mount your Google Drive.
# When you are ready, run the following lines of code.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import a file into a pandas dataframe
import pandas as pd
carAuction = pd.read_csv("/content/drive/My Drive/carAuction.csv")

# %%
carAuction.head(10)
# Out:
#   Auction   Color IsBadBuy  ...  VehOdo WarrantyCost WheelType
# 0   ADESA   WHITE       No  ...   75419          869     Alloy
# 1   ADESA    GOLD      Yes  ...   82944         2322     Alloy
# 2   ADESA     RED       No  ...   57338          588     Alloy
# 3   ADESA    GOLD       No  ...   55909         1169     Alloy
# 4   ADESA    GREY       No  ...   86702          853     Alloy
# 5   ADESA  SILVER       No  ...   73810         1455    Covers
# 6   ADESA     RED       No  ...   85003         1633    Covers
# 7   ADESA  SILVER       No  ...   88991         2152    Covers
# 8   ADESA  SILVER       No  ...   80077         1373     Alloy
# 9   ADESA  MAROON       No  ...   71952         1272     Alloy
#
# [10 rows x 11 columns]

# %%
carAuction.head(5)
# Out:
#   Auction  Color IsBadBuy  ...  VehOdo WarrantyCost WheelType
# 0   ADESA  WHITE       No  ...   75419          869     Alloy
# 1   ADESA   GOLD      Yes  ...   82944         2322     Alloy
# 2   ADESA    RED       No  ...   57338          588     Alloy
# 3   ADESA   GOLD       No  ...   55909         1169     Alloy
# 4   ADESA   GREY       No  ...   86702          853     Alloy
#
# [5 rows x 11 columns]

# %%
# plot a scatter plot of the values in two columns of carAuction
# https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.html
# https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.figure.html#matplotlib.pyplot.figure
# https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter

import matplotlib.pyplot as plt
plt.figure()

plt.scatter(carAuction['MMRCurrentAuctionAveragePrice'],carAuction['VehBCost']);
